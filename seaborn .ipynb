# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.drop(columns=['Id'],inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.countplot(df.Species)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(df.SepalLengthCm,df.SepalWidthCm)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.iloc[:,:4]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
sns.histplot(df.iloc[:,:4])

# %%
sns.boxplot(df.iloc[:,:4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-64a7877ebd96> in <module>
# ----> 1 sns.boxplot(df.iloc[:,:4])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
# -> 2242                           width, dodge, fliersize, linewidth)
#    2243
#    2244     if ax is None:
#
# ...

# %%
sns.boxplot(df.iloc[:,:4])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-64a7877ebd96> in <module>
# ----> 1 sns.boxplot(df.iloc[:,:4])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.heatmap(df.iloc[:,:4])

# %%
sns.pairplot(df)

# %%
tips = sns.load_dataset('tips')

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.iloc[:,2:6].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-9fab4db5af4a> in <module>
# ----> 1 tips.iloc[:,2:6].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
tips[['sex','smoker']].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-d04018318780> in <module>
# ----> 1 tips[['sex','smoker']].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
pd.unique([tips.sex,tips.smoker])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-fb80bba8b23d> in <module>
# ----> 1 pd.unique([tips.sex,tips.smoker])
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# --> 382     uniques = table.unique(values)
#     383     uniques = _reconstruct_data(uniques, original.dtype, original)
#     384     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1797     def __hash__(self):
#    1798         raise TypeError(
# -> 1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
# ...

# %%
tips.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
sel_columns_val=tips.iloc[:,2:6]

# %%
sel_columns_val
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
for sex in sel_columns_val:
    print(df[col].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-177e9b0f4114> in <module>
#       1 for sex in sel_columns_val:
# ...

# %%
for col in tips:
    print(df[col].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_bill'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-fd210a4a61b3> in <module>
#       1 for col in tips:
# ...

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.groupby(['sex','smoker','day','time']).size()
# Out:
# sex     smoker  day   time
# Male    Yes     Thur  Lunch     10
#                       Dinner     0
#                 Fri   Lunch      3
#                       Dinner     5
#                 Sat   Lunch      0
#                       Dinner    27
#                 Sun   Lunch      0
#                       Dinner    15
#         No      Thur  Lunch     20
#                       Dinner     0
#                 Fri   Lunch      0
#                       Dinner     2
#                 Sat   Lunch      0
#                       Dinner    32
#                 Sun   Lunch      0
#                       Dinner    43
# Female  Yes     Thur  Lunch      7
#                       Dinner     0
#                 Fri   Lunch      3
#                       Dinner     4
#                 Sat   Lunch      0
#                       Dinner    15
#                 Sun   Lunch      0
#                       Dinner     4
#         No      Thur  Lunch     24
#                       Dinner     1
# ...

# %%
tips.smoker.value_counts(normalize=True)
# Out:
# No     0.618852
# Yes    0.381148
# Name: smoker, dtype: float64

# %%
for col in tips:
    print(tips[col].value_counts())
# Out:
# 13.42    3
# 10.33    2
# 20.29    2
# 18.29    2
# 17.92    2
#         ..
# 30.40    1
# 26.59    1
# 19.65    1
# 9.55     1
# 5.75     1
# Name: total_bill, Length: 229, dtype: int64
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 2.83     1
# 1.58     1
# 3.71     1
# 3.35     1
# 2.18     1
# Name: tip, Length: 123, dtype: int64
# Male      157
# Female     87
# Name: sex, dtype: int64
# No     151
# Yes     93
# Name: smoker, dtype: int64
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64
# Dinner    176
# Lunch      68
# Name: time, dtype: int64
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
sns.countplot(tips)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-368b29fc6c59> in <module>
# ----> 1 sns.countplot(tips)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
# ...

# %%
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.sex)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.relplot(tips.tip,tips.size,hue=tips.smoker)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(tips['total_bill'])

# %%
sns.histplot(tips[['total_bill','tip']])

# %%
tips[tips['total_bill','tip']]
#sns.heatmap(tips,)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('total_bill', 'tip')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-32b0e6e55597> in <module>
# ----> 1 tips[tips['total_bill','tip']]
# ...

# %%
tips[['tip','total_bill','size']]
# Out:
#       tip  total_bill  size
# 0    1.01       16.99     2
# 1    1.66       10.34     3
# 2    3.50       21.01     3
# 3    3.31       23.68     2
# 4    3.61       24.59     4
# ..    ...         ...   ...
# 239  5.92       29.03     3
# 240  2.00       27.18     2
# 241  2.00       22.67     2
# 242  1.75       17.82     2
# 243  3.00       18.78     2
#
# [244 rows x 3 columns]

# %%
tips[tips['size']==2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [156 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.lmplot(data=tips[['tip','total_bill']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-2342a5b26668> in <module>
# ----> 1 sns.lmplot(data=tips[['tip','total_bill']])
#
# ...

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
np.random.seed(20)
n = 2_000  #size
data = {
    'A': np.random.normal(loc = 100, scale = 1, size = n),
    'B': np.random.normal(loc = 100, scale = 2, size = n),
    'C': np.random.normal(loc = 100, scale = 5, size = n),
    'D': np.random.lognormal(mean = 2, sigma = 1.1, size = n),
    'E': np.random.lognormal(mean = 2, sigma = 1.2, size = n),
    'F': np.random.lognormal(mean = 2, sigma = 1.3, size = n),
    'G': np.random.randn(n),
    'H': np.random.binomial(n = 10, p = 0.8, size = n)
}
 
df = pd.DataFrame(data)
df.head()
# Out:
#             A           B           C          D          E          F  \
# 0  100.883893  102.445802  105.389348   4.301081   1.588100   5.090603
# 1  100.195865   99.007382  106.483443   2.039321   1.486563   6.697147
# 2  100.357537   96.341847   96.661463   3.010788   3.249671   9.179327
# 3   97.656738  100.241640  106.762574  10.485774  29.973364   3.502739
# 4   98.915167  100.602171   97.836077  23.349188   1.070186  25.273968
#
#           G   H
# 0 -0.257072   8
# 1  2.078837  10
# 2 -1.513925   8
# 3 -0.817592   7
# 4  0.543835   9

# %%
sns.kdeplot(df['A'])

# %%
sns.kdeplot(df['B'])

# %%
sns.kdeplot(df['C'])

# %%
sns.kdeplot(df['D'])

# %%
sns.kdeplot(df['E'])

# %%
sns.kdeplot(df['F'])

# %%
sns.joinplot(df['A'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-ceaee181f68f> in <module>
# ----> 1 sns.joinplot(df['A'])
#
# AttributeError: module 'seaborn' has no attribute 'joinplot'

# %%
sns.histplot(df)

# %%
sns.violinplot(df['G'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(df['H'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
series = pd.read_csv( 'Airline_passengers.csv' , header=0, index_col=0, parse_dates=True,
squeeze=True)
series.describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: Airline_passengers, dtype: float64

# %%
series.shape
# Out:
# (144,)

# %%
sns.barplot(x=series.index,data=series)

# %%
sns.lineplot(data=series)

# %%
sns.boxplot(data=series)

# %%
sns.histplot(data=series)

# %%
sns.kdeplot(data=series)
