# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('respirators_distribution_Brazil.csv',sep=';')

# %%
df
# Out:
#             DATA           FORNECEDOR         DESTINO ESTADO/MUNICIPIO  \
# 0     19/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 1     22/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 2     08/05/2020             MAGNAMED  RIO DE JANEIRO           ESTADO
# 3     08/05/2020                  KTK  RIO DE JANEIRO           ESTADO
# 4     09/05/2020             LEISTUNG  RIO DE JANEIRO           ESTADO
# ...          ...                  ...             ...              ...
# 1600  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1601  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1602  24/09/2020                  KTK          PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA          PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED          LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 0                UTI          40   2400000
# ...

# %%
df.head(10)
# Out:
#          DATA FORNECEDOR         DESTINO ESTADO/MUNICIPIO        TIPO  \
# 0  19/04/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 1  22/04/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 2  08/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
# 3  08/05/2020        KTK  RIO DE JANEIRO           ESTADO         UTI
# 4  09/05/2020   LEISTUNG  RIO DE JANEIRO           ESTADO         UTI
# 5  09/05/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 6  09/05/2020     VYAIRE  RIO DE JANEIRO           ESTADO         UTI
# 7  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
# 8  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO  TRANSPORTE
# 9  09/05/2020   MAGNAMED  RIO DE JANEIRO           ESTADO         UTI
#
#    QUANTIDADE    VALOR                                       DESTINATARIO  UF
# 0          40  2400000  ALMOXARIFADO ESTADUAL DE MEDICAMENTOS - RIO DE...  RJ
# ...

# %%
df.tail(3)
# Out:
#             DATA           FORNECEDOR DESTINO ESTADO/MUNICIPIO  \
# 1602  24/09/2020                  KTK  PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA  PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED  LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 1602             UTI           2    120000
# 1603  TRANSPORTE USA           1     63125
# 1604      TRANSPORTE         300  14487000
#
#                                 DESTINATARIO  UF
# 1602                           SMS de GUAIRA  PR
# 1603                           SMS de GUAIRA  PR
# 1604  MISSÃO FAB (Doação Destino ao Libano).   -

# %%
df.columns
# Out:
# Index(['DATA', 'FORNECEDOR', 'DESTINO', 'ESTADO/MUNICIPIO', 'TIPO',
#        'QUANTIDADE', 'VALOR', 'DESTINATARIO', 'UF'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1605 entries, 0 to 1604
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DATA              1605 non-null   object
#  1   FORNECEDOR        1605 non-null   object
#  2   DESTINO           1605 non-null   object
#  3   ESTADO/MUNICIPIO  1605 non-null   object
#  4   TIPO              1605 non-null   object
#  5   QUANTIDADE        1605 non-null   int64
#  6   VALOR             1605 non-null   int64
#  7   DESTINATARIO      1605 non-null   object
#  8   UF                1605 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 113.0+ KB

# %%
df.dtypes
# Out:
# DATA                object
# FORNECEDOR          object
# DESTINO             object
# ESTADO/MUNICIPIO    object
# TIPO                object
# QUANTIDADE           int64
# VALOR                int64
# DESTINATARIO        object
# UF                  object
# dtype: object

# %%
df.shape[0]
# Out:
# 1605

# %%
df.isnull().sum()
# Out:
# DATA                0
# FORNECEDOR          0
# DESTINO             0
# ESTADO/MUNICIPIO    0
# TIPO                0
# QUANTIDADE          0
# VALOR               0
# DESTINATARIO        0
# UF                  0
# dtype: int64

# %%
df
# Out:
#             DATA           FORNECEDOR         DESTINO ESTADO/MUNICIPIO  \
# 0     19/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 1     22/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 2     08/05/2020             MAGNAMED  RIO DE JANEIRO           ESTADO
# 3     08/05/2020                  KTK  RIO DE JANEIRO           ESTADO
# 4     09/05/2020             LEISTUNG  RIO DE JANEIRO           ESTADO
# ...          ...                  ...             ...              ...
# 1600  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1601  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1602  24/09/2020                  KTK          PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA          PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED          LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 0                UTI          40   2400000
# ...

# %%
pd.to_datetime(df.DATA)
# Out:
# 0      2020-04-19
# 1      2020-04-22
# 2      2020-08-05
# 3      2020-08-05
# 4      2020-09-05
#           ...
# 1600   2020-09-21
# 1601   2020-09-21
# 1602   2020-09-24
# 1603   2020-09-24
# 1604   2020-07-08
# Name: DATA, Length: 1605, dtype: datetime64[ns]

# %%
df.DATA.astype(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-f74176995f65> in <module>
# ----> 1 df.DATA.astype(pd.to_datetime)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df.DATA.astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-bcdbc314e9cd> in <module>
# ----> 1 df.DATA.astype('datetime64[ns]',inplace=True)
#
# TypeError: astype() got an unexpected keyword argument 'inplace'

# %%
df
# Out:
#             DATA           FORNECEDOR         DESTINO ESTADO/MUNICIPIO  \
# 0     19/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 1     22/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 2     08/05/2020             MAGNAMED  RIO DE JANEIRO           ESTADO
# 3     08/05/2020                  KTK  RIO DE JANEIRO           ESTADO
# 4     09/05/2020             LEISTUNG  RIO DE JANEIRO           ESTADO
# ...          ...                  ...             ...              ...
# 1600  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1601  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1602  24/09/2020                  KTK          PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA          PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED          LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 0                UTI          40   2400000
# ...

# %%
df.dtypes
# Out:
# DATA                object
# FORNECEDOR          object
# DESTINO             object
# ESTADO/MUNICIPIO    object
# TIPO                object
# QUANTIDADE           int64
# VALOR                int64
# DESTINATARIO        object
# UF                  object
# dtype: object

# %%
df=df.DATA.astype('datetime64[ns]')

# %%
df
# Out:
# 0      2020-04-19
# 1      2020-04-22
# 2      2020-08-05
# 3      2020-08-05
# 4      2020-09-05
#           ...
# 1600   2020-09-21
# 1601   2020-09-21
# 1602   2020-09-24
# 1603   2020-09-24
# 1604   2020-07-08
# Name: DATA, Length: 1605, dtype: datetime64[ns]

# %%
df
# Out:
#             DATA           FORNECEDOR         DESTINO ESTADO/MUNICIPIO  \
# 0     19/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 1     22/04/2020               VYAIRE  RIO DE JANEIRO           ESTADO
# 2     08/05/2020             MAGNAMED  RIO DE JANEIRO           ESTADO
# 3     08/05/2020                  KTK  RIO DE JANEIRO           ESTADO
# 4     09/05/2020             LEISTUNG  RIO DE JANEIRO           ESTADO
# ...          ...                  ...             ...              ...
# 1600  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1601  21/09/2020             LEISTUNG          PARANA        MUNICIPIO
# 1602  24/09/2020                  KTK          PARANA        MUNICIPIO
# 1603  24/09/2020  VYAIRE LTV 2200 USA          PARANA        MUNICIPIO
# 1604  07/08/2020             MAGNAMED          LIBANO                -
#
#                 TIPO  QUANTIDADE     VALOR  \
# 0                UTI          40   2400000
# ...

# %%
df=df.astype({'DATA': 'datetime64[ns]','VALOR':'float'})

# %%
df
# Out:
#            DATA           FORNECEDOR         DESTINO ESTADO/MUNICIPIO  \
# 0    2020-04-19               VYAIRE  RIO DE JANEIRO           ESTADO
# 1    2020-04-22               VYAIRE  RIO DE JANEIRO           ESTADO
# 2    2020-08-05             MAGNAMED  RIO DE JANEIRO           ESTADO
# 3    2020-08-05                  KTK  RIO DE JANEIRO           ESTADO
# 4    2020-09-05             LEISTUNG  RIO DE JANEIRO           ESTADO
# ...         ...                  ...             ...              ...
# 1600 2020-09-21             LEISTUNG          PARANA        MUNICIPIO
# 1601 2020-09-21             LEISTUNG          PARANA        MUNICIPIO
# 1602 2020-09-24                  KTK          PARANA        MUNICIPIO
# 1603 2020-09-24  VYAIRE LTV 2200 USA          PARANA        MUNICIPIO
# 1604 2020-07-08             MAGNAMED          LIBANO                -
#
#                 TIPO  QUANTIDADE       VALOR  \
# 0                UTI          40   2400000.0
# ...

# %%
df.dtypes
# Out:
# DATA                datetime64[ns]
# FORNECEDOR                  object
# DESTINO                     object
# ESTADO/MUNICIPIO            object
# TIPO                        object
# QUANTIDADE                   int64
# VALOR                      float64
# DESTINATARIO                object
# UF                          object
# dtype: object

# %%
df
# Out:
#            DATA           FORNECEDOR         DESTINO ESTADO/MUNICIPIO  \
# 0    2020-04-19               VYAIRE  RIO DE JANEIRO           ESTADO
# 1    2020-04-22               VYAIRE  RIO DE JANEIRO           ESTADO
# 2    2020-08-05             MAGNAMED  RIO DE JANEIRO           ESTADO
# 3    2020-08-05                  KTK  RIO DE JANEIRO           ESTADO
# 4    2020-09-05             LEISTUNG  RIO DE JANEIRO           ESTADO
# ...         ...                  ...             ...              ...
# 1600 2020-09-21             LEISTUNG          PARANA        MUNICIPIO
# 1601 2020-09-21             LEISTUNG          PARANA        MUNICIPIO
# 1602 2020-09-24                  KTK          PARANA        MUNICIPIO
# 1603 2020-09-24  VYAIRE LTV 2200 USA          PARANA        MUNICIPIO
# 1604 2020-07-08             MAGNAMED          LIBANO                -
#
#                 TIPO  QUANTIDADE       VALOR  \
# 0                UTI          40   2400000.0
# ...

# %%
df.FORNECEDOR.unique()
# Out:
# array(['VYAIRE', 'MAGNAMED', 'KTK', 'LEISTUNG', 'LEISTUNG/VYAIRE',
#        'KTK/VAYIRE', 'WEG', 'VYAIRE LTV 2200 USA', 'UTI',
#        'VYAIRE LTV 1200 USA', 'MAGNAMED-REQUISIÇÃO',
#        'SUZANO/Zhongxun Medical', 'SUZANO/Resmed',
#        'L C DADDE COM AT INST MAT MEDICO EPP', 'MAGNAMED/REQUISIÇÃO',
#        'Leistung'], dtype=object)

# %%
df.TIPO.unique()
# Out:
# array(['UTI', 'TRANSPORTE', 'TRANSPORTE USA', 'Transporte'], dtype=object)

# %%
df.DESTINATARIO.unique()
# Out:
# array(['ALMOXARIFADO ESTADUAL DE MEDICAMENTOS - RIO DE JANEIRO',
#        'LABORATÓRIO QUÍMICO FARMACÊUTICO DE AERONÁUTICA', 'FIOCRUZ ',
#        'HOSPITAL GERAL DO BOM SUCESSO',
#        'SECRETARIA MUNICIPAL DE SAUDE - RIO DE JANEIRO',
#        'Secretaria Municipal de Saúde (BELFORD ROXO)',
#        'Secretaria Municipal de Saúde (DUQUE DE CAXIAS)',
#        'Secretaria Municipal de Saúde (ITAGUAÍ)',
#        'Secretaria Municipal de Saúde (MAJÉ)',
#        'Secretaria Municipal de Saúde (NITÉROI)',
#        'Secretaria Municipal de Saúde (NOVA FRIBURGO)',
#        'Secretaria Municipal de Saúde (NOVA IGUAÇU)',
#        'Secretaria Municipal de Saúde (PARACAMBI)',
#        'Secretaria Municipal de Saúde (QUEIMADOS)',
#        'Secretaria Municipal de Saúde (RIO BONITO)',
#        'Secretaria Municipal de Saúde (SÃO JOÃO DO MERETI)',
#        'Secretaria Municipal de Saúde (VOLTA REDONDA)',
#        'Hospital Doutor Luiz Palmier',
# ...

# %%
df.to_csv('respirators_distribution_Brazil-modified.csv',sep=';')

# %%
df.to_excel('a.xlsx')

# %%
df=pd.read_csv('CardioGoodFitness.csv')
df.shape
# Out:
# (180, 9)

# %%
df.head(3)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66

# %%
df.tail(3)
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 177    160
# 178    120
# 179    180

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df=df.astype({'Income':'float'})

# %%
df.dtypes
# Out:
# Product           object
# Age                int64
# Gender            object
# Education          int64
# MaritalStatus     object
# Usage              int64
# Fitness            int64
# Income           float64
# Miles              int64
# dtype: object

# %%
df.Product.unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
df.MaritalStatus.unique()
# Out:
# array(['Single', 'Partnered'], dtype=object)

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df.to_json()
# Out:
# '{"Product":{"0":"TM195","1":"TM195","2":"TM195","3":"TM195","4":"TM195","5":"TM195","6":"TM195","7":"TM195","8":"TM195","9":"TM195","10":"TM195","11":"TM195","12":"TM195","13":"TM195","14":"TM195","15":"TM195","16":"TM195","17":"TM195","18":"TM195","19":"TM195","20":"TM195","21":"TM195","22":"TM195","23":"TM195","24":"TM195","25":"TM195","26":"TM195","27":"TM195","28":"TM195","29":"TM195","30":"TM195","31":"TM195","32":"TM195","33":"TM195","34":"TM195","35":"TM195","36":"TM195","37":"TM195","38":"TM195","39":"TM195","40":"TM195","41":"TM195","42":"TM195","43":"TM195","44":"TM195","45":"TM195","46":"TM195","47":"TM195","48":"TM195","49":"TM195","50":"TM195","51":"TM195","52":"TM195","53":"TM195","54":"TM195","55":"TM195","56":"TM195","57":"TM195","58":"TM195","59":"TM195","60":"TM195","61":"TM195","62":"TM195","63":"TM195","64":"TM195","65":"TM195","66":"TM195","67":"TM195","68":"TM195","69":"TM195","70":"TM195","71":"TM195","72":"TM195","73":"TM195","74":"TM195","75":"TM195","76":"T
# ...

# %%
html=pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')

# %%
html[1]
# Out:
#           Year  Nominal GDP(billions USD)  GDP per capita(USD)  \
# 0   2020 (est)                    20934.0                57589
# 1         2019                    21439.0                64674
# 2         2018                    20611.2                62869
# 3         2017                    19519.4                60000
# 4         2016                    18715.0                57878
# 5         2015                    18224.8                56770
# 6         2014                    17521.3                54993
# 7         2013                    16784.9                52737
# 8         2012                    16155.3                51404
# 9         2011                    15517.9                49736
# 10        2010                    14964.4                48311
# 11        2009                    14418.7                46909
# 12        2008                    14718.6                48302
# 13        2007                    14477.6                47955
# ...

# %%
html[1].to_csv('usdata.csv')

# %%
df=pd.read_csv('FAOSTAT_data_12-5-2020.csv')
df.head(10)
# Out:
#   Domain Code Domain  Area Code       Area  Element Code     Element  \
# 0          QC  Crops          9  Argentina          5419       Yield
# 1          QC  Crops          9  Argentina          5419       Yield
# 2          QC  Crops          9  Argentina          5419       Yield
# 3          QC  Crops          9  Argentina          5510  Production
# 4          QC  Crops          9  Argentina          5510  Production
# 5          QC  Crops          9  Argentina          5510  Production
# 6          QC  Crops          9  Argentina          5419       Yield
# 7          QC  Crops          9  Argentina          5419       Yield
# 8          QC  Crops          9  Argentina          5419       Yield
# 9          QC  Crops          9  Argentina          5510  Production
#
#    Item Code     Item  Year Code  Year    Unit   Value Flag  \
# 0        515   Apples       2016  2016   hg/ha  223912   Fc
# 1        515   Apples       2017  2017   hg/ha  235386   Fc
# ...

# %%
df.shape
# Out:
# (66, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       66 non-null     object
#  1   Domain            66 non-null     object
#  2   Area Code         66 non-null     int64
#  3   Area              66 non-null     object
#  4   Element Code      66 non-null     int64
#  5   Element           66 non-null     object
#  6   Item Code         66 non-null     int64
#  7   Item              66 non-null     object
#  8   Year Code         66 non-null     int64
#  9   Year              66 non-null     int64
#  10  Unit              66 non-null     object
#  11  Value             66 non-null     int64
#  12  Flag              43 non-null     object
#  13  Flag Description  66 non-null     object
# dtypes: int64(6), object(8)
# memory usage: 7.3+ KB

# %%
df.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code            int64
# Area                object
# Element Code         int64
# Element             object
# Item Code            int64
# Item                object
# Year Code            int64
# Year                 int64
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object

# %%
df.drop(columns=['Domain Code','Domain','Area'],inplace=True)

# %%
df
# Out:
#     Area Code  Element Code     Element  Item Code      Item  Year Code  Year  \
# 0           9          5419       Yield        515    Apples       2016  2016
# 1           9          5419       Yield        515    Apples       2017  2017
# 2           9          5419       Yield        515    Apples       2018  2018
# 3           9          5510  Production        515    Apples       2016  2016
# 4           9          5510  Production        515    Apples       2017  2017
# ..        ...           ...         ...        ...       ...        ...   ...
# 61        231          5419       Yield        388  Tomatoes       2017  2017
# 62        231          5419       Yield        388  Tomatoes       2018  2018
# 63        231          5510  Production        388  Tomatoes       2016  2016
# 64        231          5510  Production        388  Tomatoes       2017  2017
# 65        231          5510  Production        388  Tomatoes       2018  2018
#
# ...

# %%
df=df.astype({'Value':'float'})

# %%
df.dtypes
# Out:
# Area Code             int64
# Element Code          int64
# Element              object
# Item Code             int64
# Item                 object
# Year Code             int64
# Year                  int64
# Unit                 object
# Value               float64
# Flag                 object
# Flag Description     object
# dtype: object

# %%
df.to_csv('updatedFoast.csv')

# %%
dados = {
    'Abacate':{
        2017: 212873,
        2018: 236177,
        2019: 242932
    },    
    'Açaí':{
        2017:1335040,
        2018:1301472,
        2019:1398328
    },
    'Banana':{
        2017:6584967,
        2018:6723590,
        2019:6812708
    },    
    'Cacau':{
        2017:235809,
        2018:239318,
        2019:259425
    },    
    'Laranja':{
        2017:17492882,
        2018:16841549,
        2019:17073593
    },    
    'Maçã':{
        2017:1307642,
        2018:1203007,
        2019:1222970
    },
    'Mamão':{
        2017:1058487,
        2018:1065421,
        2019:1161808
    },    
    'Manga':{
        2017:1089882,
        2018:1320458,
        2019:1414338
    },
 
}

# %%
df=pd.DataFrame(dados)
df
# Out:
#       Abacate     Açaí   Banana   Cacau   Laranja     Maçã    Mamão    Manga
# 2017   212873  1335040  6584967  235809  17492882  1307642  1058487  1089882
# 2018   236177  1301472  6723590  239318  16841549  1203007  1065421  1320458
# 2019   242932  1398328  6812708  259425  17073593  1222970  1161808  1414338

# %%
df.sum()
# Out:
# Abacate      691982
# Açaí        4034840
# Banana     20121265
# Cacau        734552
# Laranja    51408024
# Maçã        3733619
# Mamão       3285716
# Manga       3824678
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 2017    29317582
# 2018    28930992
# 2019    29586102
# dtype: int64

# %%
df.iloc[0:1].sum(axis=1)
# Out:
# 2017    29317582
# dtype: int64

# %%
df.describe().T
# Out:
#          count          mean            std         min         25%  \
# Abacate    3.0  2.306607e+05   15770.488906    212873.0    224525.0
# Açaí       3.0  1.344947e+06   49182.087363   1301472.0   1318256.0
# Banana     3.0  6.707088e+06  114763.755264   6584967.0   6654278.5
# Cacau      3.0  2.448507e+05   12743.102618    235809.0    237563.5
# Laranja    3.0  1.713601e+07  330121.785696  16841549.0  16957571.0
# Maçã       3.0  1.244540e+06   55552.305950   1203007.0   1212988.5
# Mamão      3.0  1.095239e+06   57754.888921   1058487.0   1061954.0
# Manga      3.0  1.274893e+06  166958.299241   1089882.0   1205170.0
#
#                 50%         75%         max
# Abacate    236177.0    239554.5    242932.0
# Açaí      1335040.0   1366684.0   1398328.0
# Banana    6723590.0   6768149.0   6812708.0
# Cacau      239318.0    249371.5    259425.0
# Laranja  17073593.0  17283237.5  17492882.0
# Maçã      1222970.0   1265306.0   1307642.0
# ...

# %%
df.to_csv('tillages.csv')

# %%
df.sum(axis=1).mean()
# Out:
# 29278225.333333332

# %%
df.sum().mean()
# Out:
# 10979334.5

# %%
df.sum(axis=1).std()
# Out:
# 329323.5315511683

# %%
df.sum().std()
# Out:
# 17484467.760639146

# %%
df.sum(axis=1).var()
# Out:
# 108453988433.33334

# %%
df.sum(axis=0).var()
# Out:
# 305706612872829.7

# %%
sales = [10, 38, 47, 9, 11, 9, 21, 49, 17, 29]
index = pd.date_range(start = '12/1/2020', periods = 10)
df = pd.DataFrame(sales, index , columns = ['Daily Sales'])

# %%
df
# Out:
#             Daily Sales
# 2020-12-01           10
# 2020-12-02           38
# 2020-12-03           47
# 2020-12-04            9
# 2020-12-05           11
# 2020-12-06            9
# 2020-12-07           21
# 2020-12-08           49
# 2020-12-09           17
# 2020-12-10           29

# %%
df.mean()
# Out:
# Daily Sales    24.0
# dtype: float64

# %%
df.std()
# Out:
# Daily Sales    15.804359
# dtype: float64

# %%
df.var()
# Out:
# Daily Sales    249.777778
# dtype: float64

# %%
df.mode().iloc[0][0]
# Out:
# 9

# %%
df['Daily Sales'].sum()
# Out:
# 240

# %%
df.max()
# Out:
# Daily Sales    49
# dtype: int64

# %%
df.min()
# Out:
# Daily Sales    9
# dtype: int64

# %%
day_max_value = df.idxmax()[0]  #day with the biggest sale
day_min_value = df.idxmin()[0]  #day with the lowest sale
 
print('Descriptive statistics'.center(100, ' '))
print(f'\tMean daily sales: {df.mean()[0]}')
print(f'\tStandard deviation: {df.std()[0].round(2)}')
print(f'\tVariance: {df.var()[0].round(2)}')
print(f'\tMode: {df.mode().iloc[0][0]}')
print(f'\tTotal quantity sold in the period: {df.sum()[0]}')
print(f'\tMaximum sales value: {df.max()[0]}')
print(f"\t\tDay: {data_valor_max.strftime('%d/%m/%Y')}")
print(f'\tMinimum sales value: {df.min()[0]}')
print(f"\t\tDay: {data_valor_min.strftime('%d/%m/%Y')}")
# Out:
#                                        Descriptive statistics
# 	Mean daily sales: 24.0
# 	Standard deviation: 15.8
# 	Variance: 249.78
# 	Mode: 9
# 	Total quantity sold in the period: 240
# 	Maximum sales value: 49
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-0c457da491c5> in <module>
#       9 print(f'\tTotal quantity sold in the period: {df.sum()[0]}')
#      10 print(f'\tMaximum sales value: {df.max()[0]}')
# ---> 11 print(f"\t\tDay: {data_valor_max.strftime('%d/%m/%Y')}")
#      12 print(f'\tMinimum sales value: {df.min()[0]}')
#      13 print(f"\t\tDay: {data_valor_min.strftime('%d/%m/%Y')}")
#
# NameError: name 'data_valor_max' is not defined

# %%
df=pd.read_csv('CardioGoodFitness.csv')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df=df.astype({'Income':'float'})

# %%
df.dtypes
# Out:
# Product           object
# Age                int64
# Gender            object
# Education          int64
# MaritalStatus     object
# Usage              int64
# Fitness            int64
# Income           float64
# Miles              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.Age.value_counts()
# Out:
# 25    25
# 23    18
# 26    12
# 24    12
# 28     9
# 33     8
# 35     8
# 30     7
# 38     7
# 22     7
# 21     7
# 27     7
# 34     6
# 31     6
# 29     6
# 40     5
# 20     5
# 32     4
# 19     4
# 37     2
# 45     2
# 48     2
# 47     2
# 50     1
# 36     1
# 39     1
# 41     1
# 42     1
# 43     1
# 44     1
# 46     1
# 18     1
# Name: Age, dtype: int64

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    28.565789
# Male      28.951923
# Name: Age, dtype: float64

# %%
df.groupby('Gender')['Age'].std()
# Out:
# Gender
# Female    6.342104
# Male      7.377978
# Name: Age, dtype: float64

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df.MaritalStatus
# Out:
# 0         Single
# 1         Single
# 2      Partnered
# 3         Single
# 4      Partnered
#          ...
# 175       Single
# 176       Single
# 177       Single
# 178    Partnered
# 179    Partnered
# Name: MaritalStatus, Length: 180, dtype: object

# %%
a=df.groupby('Gender')['MaritalStatus'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-121-b661011ec5ea> in <module>
# ----> 1 a=df.groupby('Gender')['MaritalStatus'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1230         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1231         return self._cython_agg_general(
# -> 1232             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1233         )
#    1234
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     905
#     906         if len(output) == 0:
# --> 907             raise DataError("No numeric types to aggregate")
#     908
#     909         return self._wrap_aggregated_output(output)
#
# DataError: No numeric types to aggregate

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 0     TM195   18    Male         14        Single      3        4   29562.0
# 1     TM195   19    Male         15        Single      2        3   31836.0
# 2     TM195   19  Female         14     Partnered      4        3   30699.0
# 3     TM195   19    Male         12        Single      3        3   32973.0
# 4     TM195   20    Male         13     Partnered      4        2   35247.0
# ..      ...  ...     ...        ...           ...    ...      ...       ...
# 175   TM798   40    Male         21        Single      6        5   83416.0
# 176   TM798   42    Male         18        Single      5        4   89641.0
# 177   TM798   45    Male         16        Single      5        5   90886.0
# 178   TM798   47    Male         18     Partnered      4        5  104581.0
# 179   TM798   48    Male         18     Partnered      4        5   95508.0
#
#      Miles
# 0      112
# 1       75
# 2       66
# ...

# %%
df.groupby('Gender')['Education'].mean()
# Out:
# Gender
# Female    15.394737
# Male      15.701923
# Name: Education, dtype: float64

# %%
df.groupby('Gender')['Education'].max()
# Out:
# Gender
# Female    21
# Male      21
# Name: Education, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df.MaritalStatus.value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
df[['MaritalStatus','Gender']]
# Out:
#     MaritalStatus  Gender
# 0          Single    Male
# 1          Single    Male
# 2       Partnered  Female
# 3          Single    Male
# 4       Partnered    Male
# ..            ...     ...
# 175        Single    Male
# 176        Single    Male
# 177        Single    Male
# 178     Partnered    Male
# 179     Partnered    Male
#
# [180 rows x 2 columns]

# %%
df.groupby(["Gender", "MaritalStatus"]).size()
# Out:
# Gender  MaritalStatus
# Female  Partnered        46
#         Single           30
# Male    Partnered        61
#         Single           43
# dtype: int64

# %%
df.groupby(["Gender", "Education"]).size()
# Out:
# Gender  Education
# Female  13            1
#         14           30
#         15            2
#         16           35
#         18            7
#         21            1
# Male    12            3
#         13            4
#         14           25
#         15            3
#         16           50
#         18           16
#         20            1
#         21            2
# dtype: int64

# %%
df.groupby("Gender")["MaritalStatus"].size()
# Out:
# Gender
# Female     76
# Male      104
# Name: MaritalStatus, dtype: int64

# %%
df.groupby("Gender")["Education"].size()
# Out:
# Gender
# Female     76
# Male      104
# Name: Education, dtype: int64

# %%
df.value_counts(["Gender", "Education"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-11693718e571> in <module>
# ----> 1 df.value_counts(["Gender", "Education"])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df_solution = df.pivot_table(index=["Gender", "Education"], aggfunc='size')
df_solution
# Out:
# Gender  Education
# Female  13            1
#         14           30
#         15            2
#         16           35
#         18            7
#         21            1
# Male    12            3
#         13            4
#         14           25
#         15            3
#         16           50
#         18           16
#         20            1
#         21            2
# dtype: int64

# %%
print(pd.__version__)
# Out:
# 1.0.1

# %% [markdown]
# <h1>Update after pandas 1.1 value_counts now accept multiple columns</h1>
#
# df.value_counts(["Group", "Size"])

# %%
df.cov()
# Out:
#                     Age     Education        Usage      Fitness        Income  \
# Age           48.212166      3.149410     0.113470     0.406828  5.884446e+04
# Education      3.149410      2.614867     0.693172     0.636623  1.670472e+04
# Usage          0.113470      0.693172     1.176785     0.695469  9.303043e+03
# Fitness        0.406828      0.636623     0.695469     0.919429  8.467925e+03
# Income     58844.463439  16704.717815  9303.042582  8467.925388  2.724706e+08
# Miles         13.186530     25.770795    42.709808    39.073246  4.652654e+05
#
#                    Miles
# Age            13.186530
# Education      25.770795
# Usage          42.709808
# Fitness        39.073246
# Income     465265.361887
# Miles        2689.833489

# %%
df.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
df.Age.plot(kind='hist')

# %%
df.plot(kind='hist',figsize=(10,5))

# %%
df.Gender.value_counts().plot(kind='pie',figsize=(10,5))
